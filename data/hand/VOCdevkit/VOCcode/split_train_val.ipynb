# %%
def getTargetIds(jsonData, img_name):
    for dest in jsonData:
        path_list = dest['filename'].split(os.sep)
        path_list_len = len(path_list)
        if(path_list[path_list_len - 1] == img_name):
            #print("filename:", path_list[path_list_len - 1])
            return dest['annotations']

# %%
def find_values(id, json_repr):
    results = []

    def _decode_dict(a_dict):
        try: results.append(a_dict[id])
        except KeyError: pass
        return a_dict

    json.loads(json_repr, object_hook=_decode_dict)  # return value ignored
    return results

# %%
def create_annontations(img_name, source, fishId, hsuDataAugmentation, rotationAugmentation):
    im=Image.open(source)
    width, height = im.size
    
    json_tag = os.path.join(path_root_images, FishJsonTags[fishId])
    #print('# img name: {}, # source: {}, # fishId: {}, # fish tag file: {}, #width: {}, #height:{}'.format(img_name, source, fishId, json_tag, width, height))
    
    jdata = json.loads(open (json_tag).read())
    annotations = getTargetIds(jdata, img_name)
    #print("annotations:", annotations)
    annotation_size = len(annotations)
    #print("annotations_size:", annotation_size)
    
    root = ET.Element("annotation")
    ET.SubElement(root, "folder").text = "VOCFish"
    ET.SubElement(root, "filename").text = img_name
    source = ET.SubElement(root, "source")
    ET.SubElement(source, "database").text = "Kggle"
    owner = ET.SubElement(root, "owner")
    ET.SubElement(owner, "name").text = "Leo"
    
    image_size = ET.SubElement(root, "size")
    ET.SubElement(image_size, "width").text = str(width)
    ET.SubElement(image_size, "height").text = str(height)
    ET.SubElement(image_size, "depth").text = '3'
    
    ET.SubElement(root, "segmented").text = "0"
    
    for i in range(annotation_size):
        fish_object = ET.SubElement(root, "object")
        ET.SubElement(fish_object, "name").text = FishNamesLow[fishId]
        ET.SubElement(fish_object, "pose").text = "Unspecified"
        ET.SubElement(fish_object, "truncated").text = '0'
        ET.SubElement(fish_object, "difficult").text ='0'
        
        x_start = annotations[i]['x']
        x_start = 1 if x_start <= 0 else x_start
        x_end = annotations[i]['x'] + annotations[i]['width']
        x_end = width-1 if x_end >= width else x_end
        y_start = annotations[i]['y']
        y_start = 1 if y_start <= 0 else y_start
        y_end =  annotations[i]['y'] + annotations[i]['height']
        y_end = height-1 if y_end >= height else y_end
        
        bndbox = ET.SubElement(fish_object, "bndbox")
        ET.SubElement(bndbox, "xmin").text = str(x_start)
        ET.SubElement(bndbox, "ymin").text = str(y_start)
        ET.SubElement(bndbox, "xmax").text = str(x_end)
        ET.SubElement(bndbox, "ymax").text = str(y_end)
        
    tree = ET.ElementTree(root)
    annotationsfile = os.path.join(dir_images_annotations_full, os.path.splitext(img)[0] + ".xml")
    tree.write(annotationsfile)
    
    if(hsuDataAugmentation):
        annotationsfile = os.path.join(dir_images_annotations_full, 'v'+ os.path.splitext(img)[0] + ".xml")
        tree.write(annotationsfile)
        
    if(rotationAugmentation):
        for j in range(3):
            if(j==1):
                for i in range(annotation_size):
                    fish_object = ET.SubElement(root, "object")
                    ET.SubElement(fish_object, "name").text = FishNamesLow[fishId]
                    ET.SubElement(fish_object, "pose").text = "Unspecified"
                    ET.SubElement(fish_object, "truncated").text = '0'
                    ET.SubElement(fish_object, "difficult").text ='0'

                    x_start = annotations[i]['x']
                    x_start = 1 if x_start <= 0 else x_start
                    x_end = annotations[i]['x'] + annotations[i]['width']
                    x_end = width-1 if x_end >= width else x_end
                    y_start = annotations[i]['y']
                    y_start = 1 if y_start <= 0 else y_start
                    y_end =  annotations[i]['y'] + annotations[i]['height']
                    y_end = height-1 if y_end >= height else y_end

                    bndbox = ET.SubElement(fish_object, "bndbox")
                    ET.SubElement(bndbox, "xmin").text = str(x_start)
                    ET.SubElement(bndbox, "ymin").text = str(y_start)
                    ET.SubElement(bndbox, "xmax").text = str(x_end)
                    ET.SubElement(bndbox, "ymax").text = str(y_end)
           
                annotationsfile = os.path.join(dir_images_annotations_full, 'r' + str(j) + os.path.splitext(img)[0] + ".xml")
                tree.write(annotationsfile)

# %%
def data_augmentation_hsu(target_dir, img):
    im = Image.open(os.path.join(target_dir, img))
    ld = im.load()
    width, height = im.size
    for y in range(height):
        for x in range(width):
            r,g,b = ld[x,y]
            h,s,v = colorsys.rgb_to_hsv(r/255., g/255., b/255.)
            h = (h + -90.0/360.0) % 1.0   # hue
            s = s**0.25                   # saturation
            r,g,b = colorsys.hsv_to_rgb(h, s, v)
            ld[x,y] = (int(r * 255.9999), int(g * 255.9999), int(b * 255.9999))
    #im.show()
    ####################################
    # To save the image:
    im.save(os.path.join(target_dir, 'v' + img))

# %%
def data_augmentation_rotation(target_dir, img):
    im = Image.open(os.path.join(target_dir, img))
    for j in range(3):
        if(j==1):
            im_r = im.rotate(-90*(j+1), expand=True)
            im_r.save(os.path.join(target_dir, 'r' + str(j) + img))

# %%
import os
import numpy as np
import shutil
from PIL import Image, ImageDraw
import json
import xml.etree.cElementTree as ET
import random
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import colorsys

from PIL import Image

dir_images_train_full = '../VOCHand/JPEGImages/'
dir_images_annotations_full = '../VOCHand/Annotations/'
dir_images_layout_full = '../VOCHand/ImageSets/Main/'

FishNames = ['Hand']
FishNamesLow = ['hand']

# the sum of training, val, test proportion,  must equal 1
split_train_proportion = 0.7
split_val_proportion = 0.1
split_test_proportion = 0.2

if not os.path.exists(dir_images_train_full):
    os.makedirs(dir_images_train_full)
if not os.path.exists(dir_images_annotations_full):
    os.makedirs(dir_images_annotations_full)    
if not os.path.exists(dir_images_layout_full):
    os.makedirs(dir_images_layout_full)

total_train_images = []
total_val_images = []
total_test_images = []
total_trainval_images = []

total_images = os.listdir(dir_images_train_full)
for fish_img in total_images:
    fish = fish_img.split('.')[0]
    path_ann_data = os.path.join(dir_images_annotations_full, fish+'.xml')
    #print('path_ann_data = ', path_ann_data)    
    if not os.path.exists(path_ann_data):
        print('remove = ', os.path.join(dir_images_train_full, fish_img))                          
        os.remove(os.path.join(dir_images_train_full, fish_img))
total_images = os.listdir(dir_images_train_full)     
size = len(total_images)
        
nbr_train = int(size* split_train_proportion)
nbr_val = int(size * split_val_proportion)
nbr_test = int(size * split_test_proportion)
    
random.shuffle(total_images,random.random)
train_images = total_images[:nbr_train]
val_images = total_images[nbr_train:(nbr_train+nbr_val)]
test_images = total_images[(nbr_train+nbr_val):(nbr_train+nbr_val+nbr_test)]
trainval_images = total_images[:(nbr_train+nbr_val)]
    
total_train_images.extend(train_images)
total_val_images.extend(val_images)
total_test_images.extend(test_images)
total_trainval_images.extend(trainval_images)

random.shuffle(total_train_images,random.random)
random.shuffle(total_val_images,random.random)
random.shuffle(total_test_images,random.random)
random.shuffle(total_trainval_images,random.random)

trainfile = open(os.path.join(dir_images_layout_full, 'train.txt'), 'w')
valfile = open(os.path.join(dir_images_layout_full, 'val.txt'), 'w')
trainvalfile = open(os.path.join(dir_images_layout_full, 'trainval.txt'), 'w')
testfile = open(os.path.join(dir_images_layout_full, 'test.txt'), 'w')

for img in total_train_images:
    trainfile.write("%s\n" % os.path.splitext(img)[0])
for img in total_val_images:
    valfile.write("%s\n" % os.path.splitext(img)[0])
for img in total_test_images:
    testfile.write("%s\n" % os.path.splitext(img)[0])
for img in total_trainval_images:
    trainvalfile.write("%s\n" % os.path.splitext(img)[0])
        
trainfile.close()
valfile.close()
testfile.close()
trainvalfile.close()

print('Finish splitting train and val images!')
# Out:
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_141.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_66.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_517.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_120.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_233.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_39.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_514.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1246.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1154.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_138.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_201.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_158.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_310.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_779.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_381.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_27.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_223.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_55.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_312.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_635.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_260.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_39.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_746.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_34.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1343.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_147.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1372.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1262.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_133.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_88.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_31.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_101.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_169.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_52.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_297.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_107.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_234.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_12.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_360.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_525.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_64.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_257.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_186.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_209.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_132.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_297.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_500.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_42.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_17.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_136.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_206.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_865.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_270.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1104.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1344.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_29.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_121.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_346.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_190.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1250.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_97.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_908.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1000.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_387.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_5.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_267.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1221.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_218.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_130.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_163.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_84.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_817.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1083.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_174.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_157.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_345.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_123.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_123.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_886.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_151.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_65.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_266.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_113.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_448.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_355.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_108.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1334.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_40.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_78.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_49.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_370.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_86.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_889.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_225.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_93.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_91.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_122.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_818.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_59.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1016.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_271.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_259.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_412.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_60.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_253.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_363.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_26.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_16.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1075.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_42.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_576.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1282.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_90.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_71.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_175.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_229.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_128.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_62.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1181.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_887.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_30.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_299.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_2.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_115.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_608.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_176.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_616.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_114.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1265.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_173.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_301.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_120.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_814.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_483.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_143.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1346.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_56.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_424.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_271.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_224.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_771.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1153.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_227.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_884.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_71.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_303.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1294.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_861.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_398.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_13.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1018.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_745.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_156.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_348.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_204.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_697.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_185.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_82.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_178.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_17.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_828.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_189.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_93.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_832.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_194.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_680.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_292.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_925.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_85.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1202.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_543.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_664.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_79.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_121.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_672.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1253.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_246.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_942.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_162.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_5.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_74.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_719.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_697.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_119.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_833.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_27.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_20.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_56.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1108.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_389.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_263.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_160.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_54.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_49.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_263.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_22.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_223.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_46.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1023.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_22.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_787.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_198.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_762.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_219.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1211.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_61.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_563.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_153.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_448.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_331.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_210.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1224.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_125.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_514.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_126.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_63.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_107.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_130.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_219.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1424.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_3.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_146.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_397.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_88.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_7.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_782.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_686.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_878.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_279.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_334.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1065.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_261.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_375.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_280.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_8.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1267.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_11.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_233.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_399.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_344.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_619.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_246.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_119.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_476.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_241.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_47.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_564.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_753.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_230.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_91.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_74.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1128.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_249.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_548.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_37.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_97.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_369.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_610.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_15.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_153.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_284.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_292.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_950.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1380.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_83.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_46.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_40.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_183.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_241.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_248.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_537.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_586.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_124.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_269.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_464.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_119.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1002.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_509.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_467.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_105.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1170.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_83.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_444.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_131.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_50.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_410.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_491.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_21.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_519.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_259.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_69.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_123.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_38.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_76.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_14.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_304.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_146.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_268.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_462.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_248.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_413.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_155.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_51.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_12.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_560.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_103.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_427.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_89.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_718.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_623.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_132.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_306.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_166.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1283.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_96.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_29.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_261.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_575.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_200.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_414.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_108.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_665.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1226.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_870.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_694.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_789.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_546.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_117.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_333.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_582.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_84.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_150.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_127.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_385.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1360.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_223.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_29.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_172.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1336.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_214.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1291.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_451.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_752.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_341.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1386.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1407.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_27.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_99.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_52.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_153.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_151.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_369.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_244.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1423.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_917.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_364.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_69.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_41.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_624.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_163.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_612.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_505.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_69.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1155.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_45.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_375.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_185.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_686.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_108.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_983.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_372.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_801.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_85.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_569.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1006.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_696.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_269.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_11.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_679.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_14.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_4.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_296.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_258.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_187.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_419.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_146.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_826.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_4.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_128.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_57.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_45.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_96.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_685.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1295.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_64.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_342.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_363.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_388.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1435.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_102.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_129.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1326.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_48.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_457.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_5.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_382.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_192.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_28.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_247.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_109.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_581.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_110.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_146.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_195.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_15.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_156.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_16.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_65.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_378.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_356.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_189.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_29.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_22.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_94.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_195.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_371.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1238.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_271.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_893.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_176.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1317.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_50.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_154.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_181.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_21.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_340.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_149.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_365.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_806.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_726.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_354.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_137.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_102.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_46.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_150.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_704.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_5.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_727.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_89.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_700.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_139.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_176.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_544.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_135.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_435.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_167.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_378.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_525.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_767.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_830.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_763.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_101.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_103.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_87.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_721.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_253.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1146.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_51.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_141.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_32.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_1.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_275.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_605.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_84.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_269.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_840.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1059.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_68.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_305.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_545.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_510.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_331.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_62.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_116.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_107.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_660.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1162.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_368.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_262.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_64.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_53.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_111.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_108.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_156.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1158.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_132.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_75.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_43.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_338.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_41.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_957.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_981.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_313.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_367.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1206.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_132.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_22.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_438.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_107.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_694.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_109.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1373.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_241.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_95.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_645.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_109.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_936.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_139.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_198.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_7.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_162.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_144.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_39.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_873.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_289.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_786.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_430.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_247.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_128.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_253.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1084.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_19.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_731.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_216.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_913.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_134.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_270.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_17.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_173.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_126.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_319.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_3.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_31.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_350.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_168.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_599.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_83.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_88.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1433.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_588.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_149.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_388.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_842.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1257.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_134.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_179.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1071.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_838.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_147.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_330.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_361.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_141.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_108.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_837.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1026.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_98.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_117.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1333.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_324.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_875.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_148.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_92.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_84.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_722.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_387.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_202.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_193.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_814.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_23.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_33.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_139.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_79.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_383.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_14.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1041.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_298.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_221.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_113.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_725.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_400.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_535.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_192.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_66.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_87.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_76.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_271.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1007.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_48.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_314.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_459.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_62.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_723.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_772.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1047.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1413.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_24.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_259.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1414.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_226.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_204.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_651.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_581.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1030.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_133.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_213.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_186.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_364.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_67.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_528.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_389.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_175.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_48.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_96.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_177.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_431.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_110.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_226.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_75.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_20.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_145.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_162.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_701.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_264.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_706.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_368.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_259.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_634.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_552.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1178.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_597.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_114.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_285.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_245.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_627.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_115.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_135.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_221.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1177.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_177.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_539.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_638.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_515.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_481.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_37.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_393.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_494.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_599.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_249.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_30.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_264.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_318.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_503.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_334.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_9.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_10.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_101.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_122.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_47.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_616.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_58.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_73.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_36.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_162.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_321.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1394.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_375.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_456.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_172.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_920.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_802.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_366.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_748.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_342.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_387.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_755.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_827.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_749.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_511.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_44.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1165.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_320.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_101.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_276.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_61.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_95.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_25.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_127.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_150.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_89.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_7.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_643.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_129.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_603.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_285.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_77.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_234.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_119.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_739.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_10.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_687.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_19.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_13.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_750.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_290.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_74.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_309.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_54.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_128.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_498.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_811.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_142.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_32.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_44.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1233.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_162.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_169.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_701.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_235.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_768.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_554.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_86.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_187.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_82.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_105.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_46.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_94.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_71.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_84.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_277.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_658.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_235.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_188.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_374.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_418.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_400.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_667.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_382.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_79.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_952.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_561.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_744.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_562.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_144.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_460.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_103.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_210.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_100.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_143.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_439.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_54.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_51.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_513.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_32.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_134.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_10.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_327.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_92.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_110.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_254.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_53.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_276.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_170.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_189.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_105.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1242.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_4.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1409.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_268.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_299.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_93.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_8.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_679.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_859.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_476.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_55.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_77.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_545.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_880.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_72.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1313.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_734.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_59.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_1.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_138.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_986.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_948.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_226.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1099.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_864.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_782.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_96.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_871.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_530.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_205.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_9.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_390.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_32.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_605.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_136.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_35.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_145.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1392.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_152.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1235.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_89.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_241.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_566.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_43.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_895.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_484.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_330.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_585.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_237.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1305.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_242.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_783.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_123.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_14.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1368.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1410.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_578.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_749.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_203.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_20.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_27.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_227.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1110.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_951.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_169.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_253.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_320.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_610.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1198.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_79.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_294.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_148.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_115.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_244.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_677.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1027.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_206.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_73.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_16.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_145.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_161.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_92.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_445.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_113.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_484.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_228.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_242.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_183.jpg')
# ...
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_399.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_89.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_55.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_99.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_319.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_44.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_268.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_81.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_154.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_958.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_245.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_349.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_108.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_352.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_40.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_76.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_94.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_80.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_106.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_129.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_910.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_135.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_333.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_9.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_239.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_355.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_15.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_117.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_63.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_54.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_370.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_9.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_60.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_8.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_6.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_4.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_114.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_66.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_434.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_114.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_613.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1150.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_571.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_765.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_795.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_348.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_145.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_818.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_2.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_54.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_59.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_214.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1275.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1216.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_508.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_352.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_753.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_61.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_52.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_73.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_99.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_114.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_221.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_91.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_315.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_78.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_71.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_213.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_449.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_215.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_303.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_143.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_740.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_48.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_104.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_362.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1043.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_265.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_238.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_148.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_327.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_72.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_104.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_83.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_604.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_215.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_308.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_243.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_635.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_10.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_166.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_56.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1009.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_268.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1205.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_260.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_606.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_24.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_362.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_38.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_36.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_90.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_223.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1032.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_577.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_118.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_240.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_773.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_13.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_82.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1236.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_28.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_152.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_24.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_177.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1194.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_324.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_125.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_128.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_855.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_713.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_191.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_21.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_275.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_374.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_239.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1079.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_18.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_166.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_40.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_454.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_40.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_524.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_555.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_38.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_13.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Buffy_336.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_125.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_105.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_454.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_212.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_64.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_413.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_142.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_114.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_94.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_187.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_26.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_272.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_157.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1382.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_593.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1196.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1268.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_105.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_397.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_704.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_166.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_225.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_136.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_217.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_1.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1384.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_319.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_103.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1102.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_450.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_82.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_83.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1431.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_315.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_132.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_63.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_131.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_139.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_266.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_261.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1052.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_40.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_391.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_714.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_11.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_12.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_702.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_82.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_323.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_803.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_79.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_299.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_394.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1179.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_21.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_66.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_86.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_527.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_401.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_437.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_203.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1121.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_150.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_243.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_1.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_34.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_118.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_791.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_990.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_311.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_317.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_197.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_464.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_536.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_115.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_961.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_744.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_178.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_124.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_98.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_147.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_25.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_673.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_730.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_181.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_650.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_122.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_927.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_6.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_380.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_200.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_19.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_111.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_926.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_245.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_80.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_224.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_79.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_921.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_209.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_196.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1322.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_664.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_131.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1402.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_49.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_234.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_494.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_173.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_50.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_489.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1080.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_forrest_95.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_695.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_542.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1258.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_357.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_443.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_463.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_101.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_152.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_51.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_805.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_208.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_91.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_587.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_107.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_80.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_25.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_95.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_23.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_403.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_162.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_boy_15.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_185.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1063.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1010.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_93.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Poselet_257.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Skin_6.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1159.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_191.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Inria_302.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_712.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_117.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_apollo13_111.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2010_1132.jpg')
# ('remove = ', '../VOCHand/JPEGImages/VOC2007_796.jpg')
# ('remove = ', '../VOCHand/JPEGImages/Movie_4weds_233.jpg')
# Finish splitting train and val images!
